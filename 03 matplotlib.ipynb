# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.array([5,12,23,26,34,31,47,67,72,75])
y = np.array([10,12,16,32,41,67,72,74,88,81])

# %%
plt.plot(x,y)

# %%
plt.scatter(x, y)

# %%
df = pd.read_csv('student.csv')

# %%
plt.bar(df['name'], df['marks'])
# Out:
# <BarContainer object of 10 artists>

# %%
studs = [45,67,79,145,111,105,34]
langs = ['C','C++','Java','Python','PHP','JavaScript','R']

# %%
plt.pie(studs, labels=langs, autopct='%2.2f%%');

# %%
studs;

# %%
plt.boxplot(df['marks']);

# %%
plt.boxplot(df['age']);

# %%
z = np.array([67,44,34,56,67,87,64,59,60,47,86,44,65,62,71])

# %%
plt.hist(z, bins = range(1,100,10));
